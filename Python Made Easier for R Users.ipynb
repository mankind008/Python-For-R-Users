# %% [markdown]
# # Welcome to Python for R Users
# This user manual is to help fellow R users to transition into python.
# Motivations:
# 1. Flexibility of a more generalized scripting language.
# 2. Faster growth as a data science platform, mainly for Artificial Nueral Networks and Deep Learning frameworks.
# 3. Open source/ community support from software developers to statisticians.

# %%
print("Python Reborn")
# Out:
# Python Reborn

# %% [markdown]
# ## This section is inspired from the MIT open courseware:
# MIT Course Number: 6.0001
# Introduction to Computer Science and Programming in Python
#
# I higly recommend this series of 12 basic but insightful lectures

# %%
# Data types : Integer, float, boolean and string


# Strings
hi = "hello there"

name = "mannu"

greet = hi + " " + name
print(greet*2)

# Taking input from the user

text = input("write anything you like... ")
print(text*5)

# input by default returns back string , to get other data type cast it respectively
num = int(input("write anything you like... "))
print(num*5)

# testing can be used with int float and string: returns a boolean
# when testing: strings handled dictionary wise (lexicographically)
print("a" < "b")

# booleans can be used to test using logic operators: not, and and or
r = True
not r
# Out:
# hello there mannuhello there mannu
# write anything you like... 2
# 22222
# write anything you like... 3
# 15
# True
# False

# %%
# control flows: if while and for

x = input("input yes or no.. ").lower()

while x != "yes" and x != "no":
        x = input("input yes or no.. ").lower()
        if x == "yes":
            print("your are optimist")
        elif x == "no":
            print("your are pessimist")
        else :
            print("WRONG INPUT")
    
for i in range(2,6,2):
    print(i)    
    
# More of strings with for loop

for n in s:
	print(n)
# Out:
# input yes or no.. No
# 2
# 4
# a
# b
# c
# d
# e

# %%
# functions
    
def function (x):
    x = x**2 + 1
    print("with return")
    return x
   
function(6)  


# swapping variables
x = 2
y = 3

x = y  
y = x  # will not swap as x has same value as y itself 

# correct swap procedure
x = 2
y = 3

temp = x
x = y
y = temp

#  Compound Data Types : Tuples and Lists (Note: Tuples and strings are immutable)
t = (1,2,3,"manik")

t = t + ("babe",)

# swap in Tuples
x = 2
y = 3  

(x,y)   =  (y,x)  

# tuple in functions

tswift = ((2014,"Katy"),
          (2014, "Harry"),
          (2012,"Jake"), 
          (2010,"Taylor"), 
          (2008,"Joe"))  


def get_data(a_tuple):
    year = ()
    people = ()
    for t in a_tuple:
        year = year + (t[0],)
        if t[1] not in people:
            people = people + (t[1],)
    min_n = min(year)
    max_n = max(year)
    unique_people = len(people)
    
    return(min_n,max_n,unique_people)

(min_n, max_n, unique_people) = get_data(tswift)

print('from', min_n, "to", max_n, "taylor swift wrote about", unique_people, "people")
    
# Lists are mutable using append (single data) and extend (adding another list) function

L = [1,5,4,2,4,5,7,5]  
L.append(9)
print(L)    

L.extend([2,5,8,7,4])
print(L)      
    
L.pop()    # returns last item in list as a function
print(L)    
    
L.remove(2)    
print(L)     

# Strings to Lists to string: Note string is immutable

s = "I<3 Maths"
list(s)    # returns a list

s.split("<")      # this returns list strings gets separated

# List to string: returns a string

l = ['a','b','c']
"".join(l)

"_".join(l)

# mutating lists

l = [1,2,3,42,2]
    
sorted(l)    # this returns a sorted list

l.sort()     # mutates the list l

l.reverse()     # mutates the list l
    
    
# Alias Lists
d = [1,2,6,4,2]
e = d
d.append(0)    # both d and e changes , if you need both to be independently handled :Clone it

# clone Lists
r = ['manik', 'is', 'hero']  
s = r[:]
r.append('dude')  # Only r changes

    
# issue of mutating lists while in loops : below one is not able to remove all duplicates from l1

l1 = [1,2,3,4]
l2 = [1,2,7,8]

def remove_dup(l1, l2):
    for e in l1:
        if e in l2:
            l1.remove(e)
 
remove_dup(l1,l2)   
    
# to correctly do the above example ietrate over a copy of list

l1 = [1,2,3,4]
l2 = [1,2,7,8]
l1_copy = l1[:]

def remove_dup(l1, l2):
    for e in l1_copy:
        if e in l2:
            l1.remove(e)
 
remove_dup(l1,l2)    


# Towers of Hanoi


def printMove(fr, to):
    print('move from ' + str(fr) + ' to ' + str(to))

def Towers(n, fr, to, spare):
    if n == 1:
        printMove(fr, to)
    else:
        Towers(n-1, fr, spare, to)
        Towers(1, fr, to, spare)
        Towers(n-1, spare, to, fr)
 

#  Counting frequencies of words in song lyrics: Using Dictionaries
    
        
def lyrics_to_frequencies(lyrics):
    myDict = {}
    for word in lyrics:
        if word in myDict:
            myDict[word] += 1
        else:
            myDict[word] = 1
    return myDict
    
    
she_loves_you = ['she', 'loves', 'you', 'yeah', 'yeah', 
'yeah','she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',

'you', 'think', "you've", 'lost', 'your', 'love',
'well', 'i', 'saw', 'her', 'yesterday-yi-yay',
"it's", 'you', "she's", 'thinking', 'of',
'and', 'she', 'told', 'me', 'what', 'to', 'say-yi-yay',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'she', 'said', 'you', 'hurt', 'her', 'so',
'she', 'almost', 'lost', 'her', 'mind',
'and', 'now', 'she', 'says', 'she', 'knows',
"you're", 'not', 'the', 'hurting', 'kind',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',

'you', 'know', "it's", 'up', 'to', 'you',
'i', 'think', "it's", 'only', 'fair',
'pride', 'can', 'hurt', 'you', 'too',
'pologize', 'to', 'her',

'Because', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'Yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'yeah', 'yeah', 'yeah',
'yeah', 'yeah', 'yeah', 'yeah'
]

beatles = lyrics_to_frequencies(she_loves_you)

# testing for palindromes

        
def isPalindrome(s):

    def toChars(s):
        s = s.lower()
        ans = ''
        for c in s:
            if c in 'abcdefghijklmnopqrstuvwxyz':
                ans = ans + c
        return ans

    def isPal(s):
        if len(s) <= 1:
            return True
        else:
            return s[0] == s[-1] and isPal(s[1:-1])

    return isPal(toChars(s))


# appending immutable vs mutable
    
s = "abc"
s.append("s")    # cant append strings: will give error, but you can concatenate

l = list(s)
l.append(2)
# Out:
# with return
# from 2008 to 2014 taylor swift wrote about 5 people
# [1, 5, 4, 2, 4, 5, 7, 5, 9]
# [1, 5, 4, 2, 4, 5, 7, 5, 9, 2, 5, 8, 7, 4]
# [1, 5, 4, 2, 4, 5, 7, 5, 9, 2, 5, 8, 7]
# [1, 5, 4, 4, 5, 7, 5, 9, 2, 5, 8, 7]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f458f9050e2b> in <module>()
#     244
#     245 s = "abc"
# --> 246 s.append("s")    # cant append strings: will give error, but you can concatenate
#     247
#     248 l = list(s)
#
# AttributeError: 'str' object has no attribute 'append'
